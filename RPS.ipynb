# %%
import random

def winner(comp,user):
    if(comp == user):
        print("Its a tie")
    else:
        if(comp == "R"):
            if(user == "P"):
                print("User wins")
            else:
                print("Computer wins")
        if(comp == "P"):
            if(user == "S"):
                print("User wins")
            else:
                print("Computer wins")
        if(comp == "S"):
            if(user == "R"):
                print("User wins")
            else:
                print("Computer wins")


r = random.randint(1,3)
if(r == 1):
    comp = "R"
elif(r == 2):
    comp = "P"
else:
    comp = "S"
    
user = input("Press R to choose Rock, P to choose Paper and S to choose Scissors\n")
print(comp)

winner(comp,user)
# Out:
# Press R to choose Rock, P to choose Paper and S to choose Scissors
# P
# P
# Its a tie

# %%
import random
comp = random.randint(1,1000)
user = None
while user!=comp:
    user = int(input("Guess the number : "))
    
    if(user > comp):
        print("The number is smaller")
    elif(user < comp):
        print("The number is greater")

print("Congratulations!! You won")
# Out:
# Guess the number : 500
# The number is smaller
# Guess the number : 250
# The number is greater
# Guess the number : 375
# The number is greater
# Guess the number : 425
# The number is greater
# Guess the number : 460
# The number is greater
# Guess the number : 480
# The number is greater
# Guess the number : 490
# The number is smaller
# Guess the number : 495
# The number is smaller
# Guess the number : 485
# Congratulations!! You won

# %%
theBoard = {'1':' ', '2':' ', '3':' ',
            '4':' ', '5':' ', '6':' ',
            '7':' ', '8':' ', '9':' '}

boardKeys = []

for keys in theBoard:
    boardKeys.append(keys)
    
def printBoard(board):
    print(board['1'] + '|' + board['2'] + '|' + board['3'])
    print('- - -')
    print(board['4'] + '|' + board['5'] + '|' + board['6'])
    print('- - -')
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    
def game():
    turn = 'X'
    count = 0
    
    for i in range(9):
        printBoard(theBoard)
        print("Player " + turn + " specify where you want to go : ")
        move = input()
        
        if(theBoard[move] == ' '):
            theBoard[move] = turn
            count = count+1
        else:
            print("Sorry this location is filled. Choose another one")
            continue
            
            # Now we will check if player X or O has won,for every move after 5 moves. 
        if count >= 5:
            if theBoard['1'] == theBoard['2'] == theBoard['3'] != ' ': # across the top
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")                
                break
            elif theBoard['4'] == theBoard['5'] == theBoard['6'] != ' ': # across the middle
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['7'] == theBoard['8'] == theBoard['9'] != ' ': # across the bottom
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['1'] == theBoard['4'] == theBoard['7'] != ' ': # down the left side
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['2'] == theBoard['5'] == theBoard['8'] != ' ': # down the middle
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['3'] == theBoard['6'] == theBoard['9'] != ' ': # down the right side
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break 
            elif theBoard['1'] == theBoard['5'] == theBoard['9'] != ' ': # diagonal
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break
            elif theBoard['3'] == theBoard['5'] == theBoard['7'] != ' ': # diagonal
                printBoard(theBoard)
                print("\nGame Over.\n")                
                print(" **** " +turn + " won. ****")
                break 

        # If neither X nor O wins and the board is full, we'll declare the result as 'tie'.
        if count == 9:
            print("\nGame Over.\n")                
            print("It's a Tie!!")

        # Now we have to change the player after every move.
        if turn =='X':
            turn = 'O'
        else:
            turn = 'X'        
    
    # Now we will ask if player wants to restart the game or not.
    restart = input("Do want to play Again?(y/n)")
    if restart == "y" or restart == "Y":  
        for key in boardKeys:
            theBoard[key] = " "

        game()

if __name__ == "__main__":
    game()
# Out:
#  | |
# - - -
#  | |
# - - -
#  | |
# Player X specify where you want to go :
# 1
# X| |
# - - -
#  | |
# - - -
#  | |
# Player O specify where you want to go :
# 2
# X|O|
# - - -
#  | |
# - - -
#  | |
# Player X specify where you want to go :
# 3
# X|O|X
# - - -
#  | |
# - - -
#  | |
# Player O specify where you want to go :
# 6
# X|O|X
# - - -
#  | |O
# - - -
#  | |
# Player X specify where you want to go :
# 9
# X|O|X
# - - -
#  | |O
# - - -
#  | |X
# Player O specify where you want to go :
# 5
# X|O|X
# - - -
#  |O|O
# - - -
#  | |X
# Player X specify where you want to go :
# 4
# X|O|X
# - - -
# X|O|O
# - - -
#  | |X
# Player O specify where you want to go :
# 7
# X|O|X
# - - -
# X|O|O
# - - -
# O| |X
# Player X specify where you want to go :
# 8
#
# Game Over.
#
# It's a Tie!!
# Do want to play Again?(y/n)y
#  | |
# - - -
#  | |
# - - -
#  | |
# Player X specify where you want to go :
# 1
# X| |
# - - -
#  | |
# - - -
#  | |
# Player O specify where you want to go :
# 2
# X|O|
# ...
